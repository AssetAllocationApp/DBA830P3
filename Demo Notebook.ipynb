# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # This is the heading

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Community_Resiliency_Indicator_System_20240601 (2).csv')

# %%
df
# Out:
#                  Neighborhood  Flood_Per  Heat_Per   Liq_Per  Haz_Score  \
# 0                     Bayview   0.068369  0.586532  0.557273        1.0
# 1              Bernal Heights   0.000000  0.104888  0.129120        3.0
# 2         Castro/Upper Market   0.000000  0.002686  0.119483        5.0
# 3                   Chinatown   0.000000  0.999761  0.312332        1.0
# 4              Crocker Amazon   0.000000  0.218043  0.019277        3.0
# 5   Diamond Heights/Glen Park   0.000000  0.000279  0.198020        4.0
# 6       Downtown/Civic Center   0.000000  0.999767  0.153798        1.0
# 7                   Excelsior   0.000000  0.345133  0.022647        3.0
# 8          Financial District   0.026447  0.674863  0.802687        1.0
# 9            Golden Gate Park   0.022587  0.000000  0.058090        NaN
# 10             Haight Ashbury   0.000000  0.061487  0.070927        4.0
# 11             Inner Richmond   0.000000  0.058091  0.007004        5.0
# ...

# %%
df_Black_Haz=df[['Black_Per','Haz_Score']].dropna(axis=0,how='any')

# %%
plt.scatter(df['Black_Per'],df['Haz_Score'])
plt.xlabel("Black %")
plt.ylabel("Hazard Score")
plt.title("Black % vs. Hazard Score")
# Out:
# Text(0.5, 1.0, 'Black % vs. Hazard Score')

# %%
def plot_two_vars(df,x_col,y_col):
    df_plot=df[[x_col,y_col]]
    fig, ax=plt.subplots()
    ax.scatter(df_plot[x_col],df_plot[y_col])
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_col)
    ax.set_title(f'{x_col} vs {y_col}')

# %%
plot_two_vars(df,"VCrim_Rate","Emp_per")
plot_two_vars(df,"Shelt_Rate","Health_Score")

# %%
sorted(df.columns)
# Out:
# ['AC_Per',
#  'AT_Min',
#  'Asian_Per',
#  'Black_Per',
#  'Citz_Per',
#  'Com_Score',
#  'DayPopDens',
#  'Dem_Score',
#  'Dis_Per',
#  'Ec_Score',
#  'EldLivAl_Per',
#  'Emp_per',
#  'Eng_Per',
#  'Env_Score',
#  'Flood_Per',
#  'Food_Score',
#  'HS_Per',
#  'Haz_Score',
#  'Health_Score',
#  'Heat_Per',
#  'House_Score',
#  'Imp_Per',
#  'Lat_Per',
#  'Liq_Per',
#  'LivAl_Per',
#  'Neighborhood',
#  'NewSF_Per',
#  'NonWhi_Per',
#  'OC_Per',
#  'Over65_Per',
#  'Over85_Per',
#  'PM_Conc',
#  'PR_Score',
#  'PTrans_Sco',
#  'Pharm_Per',
#  'PopDens',
#  'Pov_Per',
#  'PrevHos',
#  'Rent_Per',
#  'Res_Rank',
#  'Res_Score',
#  'SheltDay_Rate',
#  'Shelt_Rate',
#  'Tox_Per',
#  'Trans_Sco',
#  'Tree_Per',
#  'Under18_Per',
#  'Under5_Per',
#  'VCrim_Rate',
#  'Viol_Rate',
#  'Vot_Rate']

# %%
plots=[['Under5_Per','Under18_Per'],
       ['Food_Score','Viol_Rate'],['House_Score', 'Rent_Per']]
for pair in plots:
    plot_two_vars(df,pair[0],pair[1])

# %%
plt.hist(df["Haz_Score"],bins=5,rwidth=.7)
# Out:
# (array([7., 7., 7., 7., 8.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <BarContainer object of 5 artists>)

# %%
import geopandas as gpd
gdf=gpd.read_file('planning_neighborhoods.shp')

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
sorted(df['Neighborhood'].unique())
# Out:
# ['Bayview',
#  'Bernal Heights',
#  'Castro/Upper Market',
#  'Chinatown',
#  'Crocker Amazon',
#  'Diamond Heights/Glen Park',
#  'Downtown/Civic Center',
#  'Excelsior',
#  'Financial District',
#  'Golden Gate Park',
#  'Haight Ashbury',
#  'Inner Richmond',
#  'Inner Sunset',
#  'Lakeshore',
#  'Marina',
#  'Mission',
#  'Mission Bay',
#  'Nob Hill',
#  'Noe Valley',
#  'North Beach',
#  'Ocean View',
#  'Outer Mission',
#  'Outer Richmond',
#  'Outer Sunset',
#  'Pacific Heights',
#  'Parkside',
#  'Potrero Hill',
#  'Presidio',
#  'Presidio Heights',
#  'Russian Hill',
#  'Seacliff',
#  'South of Market',
#  'Treasure Island YBI',
#  'Twin Peaks',
#  'Visitacion Valley',
#  'West of Twin Peaks',
#  'Western Addition']

# %%
sorted(gdf['neighborho'].unique())
# Out:
# ['Bayview',
#  'Bernal Heights',
#  'Castro/Upper Market',
#  'Chinatown',
#  'Crocker Amazon',
#  'Diamond Heights',
#  'Downtown/Civic Center',
#  'Excelsior',
#  'Financial District',
#  'Glen Park',
#  'Golden Gate Park',
#  'Haight Ashbury',
#  'Inner Richmond',
#  'Inner Sunset',
#  'Lakeshore',
#  'Marina',
#  'Mission',
#  'Nob Hill',
#  'Noe Valley',
#  'North Beach',
#  'Ocean View',
#  'Outer Mission',
#  'Outer Richmond',
#  'Outer Sunset',
#  'Pacific Heights',
#  'Parkside',
#  'Potrero Hill',
#  'Presidio',
#  'Presidio Heights',
#  'Russian Hill',
#  'Seacliff',
#  'South of Market',
#  'Treasure Island/YBI',
#  'Twin Peaks',
#  'Visitacion Valley',
#  'West of Twin Peaks',
#  'Western Addition']

# %%
gdf.columns
# Out:
# Index(['neighborho', 'geometry'], dtype='object')

# %%
df_join=gdf.merge(df,left_on='neighborho',right_on='Neighborhood')

# %%
fig, ax = plt.subplots()

df_join.plot('Black_Per',legend=True, ax=ax)

df_join.plot(ax=ax, marker='o',color='none',markersize=df_join['Shelt_Rate']*10,alpha=1,edgecolor='k')
# Out:
# <Axes: >
